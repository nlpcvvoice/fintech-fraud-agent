# %%
from google.cloud import bigquery

# %%
# Initialize the BigQuery client
client = bigquery.Client()

# %%
# SQL query targeting the ULB credit card fraud dataset in BQ public data
query = """
SELECT * 
FROM `bigquery-public-data.ml_datasets.ulb_fraud_detection`
"""

# %%
# Run the query and convert to a Pandas DataFrame
df = client.query(query).to_dataframe()

# %%
# Preview your data
df.head()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 0    282.0 -0.356466  0.725418  1.971749  0.831343  0.369681 -0.107776
# 1  14332.0  1.071950  0.340678  1.784068  2.846396 -0.751538  0.403028
# 2  32799.0  1.153477 -0.047859  1.358363  1.480620 -1.222598 -0.481690
# 3  35799.0 -0.769798  0.622325  0.242491 -0.586652  0.527819 -0.104512
# 4  36419.0  1.047960  0.145048  1.624573  2.932652 -0.726574  0.690451
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.751610 -0.120166 -0.420675  ...  0.020804  0.424312 -0.015989  0.466754
# 1 -0.734920  0.205807  1.092726  ... -0.169632 -0.113604  0.067643  0.468669
# 2 -0.654461  0.128115  0.907095  ...  0.125514  0.480049 -0.025964  0.701843
# 3  0.209909  0.669861 -0.304509  ...  0.152738  0.255654 -0.130237 -0.660934
# 4 -0.627288  0.278709  0.318434  ...  0.078499  0.658942 -0.067810  0.476882
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of             Time        V1        V2        V3        V4        V5        V6  \
# 0          282.0 -0.356466  0.725418  1.971749  0.831343  0.369681 -0.107776
# 1        14332.0  1.071950  0.340678  1.784068  2.846396 -0.751538  0.403028
# 2        32799.0  1.153477 -0.047859  1.358363  1.480620 -1.222598 -0.481690
# 3        35799.0 -0.769798  0.622325  0.242491 -0.586652  0.527819 -0.104512
# 4        36419.0  1.047960  0.145048  1.624573  2.932652 -0.726574  0.690451
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  153653.0 -5.192496  3.164721 -5.047679  2.246597 -4.011781 -0.638908
# 284803   41138.0 -4.595617  5.083690 -7.581015  7.546033 -6.949165 -1.729185
# 284804   70270.0 -1.512516  1.133139 -1.601052  2.813401 -2.664503 -0.310371
# 284805   25095.0  1.192396  1.338974 -0.678876  3.123672  0.643245 -1.184323
# 284806  141565.0  0.114965  0.766762 -0.494132  0.116772  0.868169 -0.477982
#
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.181548e-15  3.448842e-16 -1.395504e-15  2.088465e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.002719e-15  1.494498e-15 -5.556467e-16  1.149614e-16 -2.414189e-15
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.to_csv("ULB.csv")

# %%
import pandas as pd

# %%
df2 = pd.read_csv("./ulb_fraud_detection.csv")

# %%
df2.shape
# Out:
# (284807, 31)

# %%
df2.head()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 0   8748.0 -1.070416  0.304517  2.777064  2.154061  0.254450 -0.448529
# 1  27074.0  1.165628  0.423671  0.887635  2.740163 -0.338578 -0.142846
# 2  28292.0  1.050879  0.053408  1.364590  2.666158 -0.378636  1.382032
# 3  28488.0  1.070316  0.079499  1.471856  2.863786 -0.637887  0.858159
# 4  31392.0 -3.680953 -4.183581  2.642743  4.263802  4.643286 -0.225053
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0 -0.398691  0.144672  1.070900  ... -0.122032 -0.182351  0.019576  0.626023
# 1 -0.055628 -0.015325 -0.213621  ... -0.081184 -0.025694 -0.076609  0.414687
# 2 -0.766202  0.486126  0.152611  ...  0.083467  0.624424 -0.157228 -0.240411
# 3 -0.687478  0.344146  0.459561  ...  0.048067  0.534713 -0.098645  0.129272
# 4 -3.733637  1.273037  0.015661  ...  0.649051  1.054124  0.795528 -0.901314
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
# !bq load \
  --source_format=CSV \
  --skip_leading_rows=1 \
  fraud_detection.ulb_credit_card_fraud \
  ulb_fraud_detection.csv
# Out:
# Upload complete.
# Waiting on bqjob_r68de820034548a92_000001a00d446c16_1 ... (3s) Current status: DONE
